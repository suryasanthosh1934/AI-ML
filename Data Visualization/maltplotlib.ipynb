# %%
pip install matplotlib # Installation of matplotlib

# %%
import matplotlib.pyplot as plt # Importing of mtaplotlib

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Student": [
        "Aarav", "Diya", "Rohan", "Ananya", "Vikram",
        "Sneha", "Arjun", "Meera", "Karan", "Ishita",
        "Rahul", "Priya", "Aditya", "Neha", "Varun",
        "Kavya", "Sanjay", "Pooja", "Nikhil", "Riya",
        "Amit", "Shreya", "Manish", "Tanvi", "Akash",
        "Simran", "Ravi", "Nandini", "Harsh", "Aisha",
        "Dev", "Anjali", "Mohit", "Sakshi", "Yash",
        "Divya", "Ritesh", "Maya", "Abhishek", "Tina",
        "Siddharth", "Preeti", "Rajat", "Swati", "Vivek",
        "Komal", "Ankit", "Lavanya", "Suresh", "Ira"
    ],

    "Age": [
        18, 19, 20, 18, 21, 19, 20, 18, 22, 19,
        20, 21, 18, 19, 20, 22, 21, 19, 18, 20,
        21, 18, 19, 20, 22, 21, 18, 19, 20, 21,
        18, 22, 19, 20, 21, 18, 19, 20, 22, 21,
        19, 18, 20, 21, 22, 19, 20, 18, 21, 19
    ],

    "Gender": [
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female"
    ],

    "Study_Hours": [
        2, 4, 3, 5, 1, 6, 4, 2, 7, 5,
        3, 6, 2, 4, 5, 8, 3, 6, 2, 7,
        4, 5, 3, 8, 6, 2, 4, 7, 5, 3,
        6, 4, 2, 8, 5, 7, 3, 6, 4, 2,
        7, 5, 3, 6, 4, 8, 2, 5, 7, 3
    ],

    "Attendance": [
        75, 88, 82, 95, 68, 91, 85, 78, 97, 89,
        81, 94, 73, 86, 90, 98, 79, 92, 71, 96,
        84, 87, 80, 99, 93, 76, 85, 95, 88, 82,
        91, 86, 74, 97, 89, 94, 83, 90, 87, 77,
        96, 88, 81, 93, 85, 98, 72, 84, 95, 80
    ],

    "Math_Score": [
        65, 82, 74, 91, 55, 88, 79, 68, 95, 84,
        72, 90, 61, 77, 86, 98, 70, 89, 58, 94,
        81, 85, 73, 97, 92, 64, 78, 90, 83, 75,
        87, 80, 62, 96, 85, 91, 76, 88, 82, 69,
        93, 84, 71, 90, 79, 95, 60, 74, 89, 72
    ],

    "English_Score": [
        70, 85, 78, 88, 60, 92, 81, 73, 94, 86,
        75, 91, 67, 80, 88, 96, 74, 90, 62, 93,
        84, 87, 76, 95, 90, 69, 82, 92, 85, 79,
        89, 83, 65, 94, 88, 93, 78, 91, 84, 72,
        95, 86, 74, 92, 81, 97, 64, 79, 90, 76
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Student  Age  Gender  Study_Hours  Attendance  Math_Score  English_Score
# 0       Aarav   18    Male            2          75          65             70
# 1        Diya   19  Female            4          88          82             85
# 2       Rohan   20    Male            3          82          74             78
# 3      Ananya   18  Female            5          95          91             88
# 4      Vikram   21    Male            1          68          55             60
# 5       Sneha   19  Female            6          91          88             92
# 6       Arjun   20    Male            4          85          79             81
# 7       Meera   18  Female            2          78          68             73
# 8       Karan   22    Male            7          97          95             94
# 9      Ishita   19  Female            5          89          84             86
# 10      Rahul   20    Male            3          81          72             75
# ...

# %%
plt.plot(df['Age'].head(),df['Student'].head()) # simple plotting # returns an plotted graph doesn't print it
plt.xlabel('Age') # naming x axis
plt.ylabel('Student') # naming Y axis
plt.title('Age vs Student') # naming the graph
plt.show() # printing the graph

# %%
avg_math = df.groupby("Gender")["Math_Score"].mean() # Bar plot

plt.bar(avg_math.index, avg_math.values)

plt.xlabel("Gender")
plt.ylabel("Average Math Score")
plt.title("Average Math Score by Gender")

plt.show()

# %%
gender_count = df["Gender"].value_counts() # Pie Chart

plt.pie(
    gender_count.values,
    labels=gender_count.index,
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")

plt.show()

# %%
plt.scatter(df["Study_Hours"], df["Math_Score"]) # scatter plot

plt.xlabel("Study Hours")
plt.ylabel("Math Score")
plt.title("Study Hours vs Math Score")

plt.show()

# %%
plt.boxplot(df["Math_Score"]) # boxplot

plt.ylabel("Math Score")
plt.title("Distribution of Math Scores")

plt.show()

# %%
plt.hist(df["Math_Score"], bins=10) # histogram

plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.title("Distribution of Math Scores")

plt.show()
